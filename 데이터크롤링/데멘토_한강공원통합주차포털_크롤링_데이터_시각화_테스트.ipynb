# %%
## 날짜, 주차장 명 기준으로 데이터 groupby
## 시각화

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import time

# %% [markdown]
# ## preprocessing

# %% [markdown]
# - preprocessing(df)

# %%
datetime_format = '%Y-%m-%d 오후 %H시 %M분 %S초'
sample_datetime = '2022-07-05 오후 8시 50분 02초'

time_result = time.strptime(sample_datetime, datetime_format)
print(time_result)
print(time_result.tm_mon)  ## 월
print(time_result.tm_mday) ## 일
print(time_result.tm_hour) ## 시
print(time_result.tm_min)  ## 분
# Out:
# time.struct_time(tm_year=2022, tm_mon=7, tm_mday=5, tm_hour=8, tm_min=50, tm_sec=2, tm_wday=1, tm_yday=186, tm_isdst=-1)
# 7
# 5
# 8
# 50

# %%
## 데이터프레임과 총 주차 가능 대수를 입력으로 받음
def preprocessing(df): #, total_parking):
    
    ## 사용률을 계산하여 새로운 열 추가
    df['사용률'] = 1 - (df['주차 가능 대수'] / df['주차 구획수']) ###################### 주차 구획 수 = 총 주차 가능 대수 ? 확인해 보아야 함!
    
    return df

# %% [markdown]
# ## visualization

# %% [markdown]
# - visualization_data(df)

# %%
from matplotlib import rc
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
font_list
# Out:
# ['C:\\Windows\\Fonts\\courbi.ttf',
#  'C:\\Windows\\Fonts\\constanz.ttf',
#  'C:\\Windows\\Fonts\\H2MJRE.TTF',
#  'C:\\Windows\\Fonts\\H2GSRB.TTF',
#  'C:\\Windows\\Fonts\\ARIALNB.TTF',
#  'C:\\Windows\\Fonts\\YuGothR.ttc',
#  'C:\\Windows\\Fonts\\ntailub.ttf',
#  'C:\\Windows\\Fonts\\segoeuib.ttf',
#  'C:\\Windows\\Fonts\\HARNGTON.TTF',
#  'C:\\Windows\\Fonts\\segoeuil.ttf',
#  'C:\\Windows\\Fonts\\GILLUBCD.TTF',
#  'C:\\Windows\\Fonts\\phagspab.ttf',
#  'C:\\Windows\\Fonts\\simsunb.ttf',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\ADVC39D.TTF',
#  'C:\\Windows\\Fonts\\ANTQUAB.TTF',
#  'C:\\Windows\\Fonts\\LSANSDI.TTF',
#  'C:\\Windows\\Fonts\\SCRIPTBL.TTF',
#  'C:\\Windows\\Fonts\\H2MJSM.TTF',
#  'C:\\Windows\\Fonts\\ROCKI.TTF',
#  'C:\\Windows\\Fonts\\Gabriola.ttf',
#  'C:\\Windows\\Fonts\\couri.ttf',
#  'C:\\Windows\\Fonts\\Candarali.ttf',
#  'C:\\Windows\\Fonts\\simsun.ttc',
#  'C:\\Windows\\Fonts\\Candara.ttf',
#  'C:\\Windows\\Fonts\\BELLI.TTF',
#  'C:\\Windows\\Fonts\\LEELAWDB.TTF',
#  'C:\\Windows\\Fonts\\msyhl.ttc',
#  'C:\\Windows\\Fonts\\ERASLGHT.TTF',
#  'C:\\Windows\\Fonts\\YuGothB.ttc',
#  'C:\\Windows\\Fonts\\GARA.TTF',
#  'C:\\Windows\\Fonts\\FRADMCN.TTF',
#  'C:\\Windows\\Fonts\\BRADHITC.TTF',
#  'C:\\Windows\\Fonts\\PERI____.TTF',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\ADVHC39E.TTF',
#  'C:\\Windows\\Fonts\\calibrii.ttf',
#  'C:\\Windows\\Fonts\\TCBI____.TTF',
#  'C:\\Windows\\Fonts\\LeelawUI.ttf',
#  'C:\\Windows\\Fonts\\HMKMMAG.TTF',
#  'C:\\Windows\\Fonts\\calibrili.ttf',
#  'C:\\Windows\\Fonts\\lucon.ttf',
#  'C:\\Windows\\Fonts\\OUTLOOK.TTF',
#  'C:\\Windows\\Fonts\\ENGR.TTF',
#  'C:\\Windows\\Fonts\\BRLNSDB.TTF',
#  'C:\\Windows\\Fonts\\arialbi.ttf',
#  'C:\\Windows\\Fonts\\phagspa.ttf',
#  'C:\\Windows\\Fonts\\timesi.ttf',
#  'C:\\Windows\\Fonts\\cambriab.ttf',
#  'C:\\Windows\\Fonts\\Hancom Gothic Regular.ttf',
#  'C:\\Windows\\Fonts\\H2MKPB.TTF',
#  'C:\\Windows\\Fonts\\CALIFB.TTF',
#  'C:\\Windows\\Fonts\\BOD_BI.TTF',
#  'C:\\Windows\\Fonts\\HANBatangExt.ttf',
#  'C:\\Windows\\Fonts\\SitkaZ.ttc',
#  'C:\\Windows\\Fonts\\INFROMAN.TTF',
#  'C:\\Windows\\Fonts\\cambriaz.ttf',
#  'C:\\Windows\\Fonts\\GIGI.TTF',
#  'C:\\Windows\\Fonts\\msyh.ttc',
#  'C:\\Windows\\Fonts\\SCHLBKBI.TTF',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\H2WULL.TTF',
#  'C:\\Windows\\Fonts\\VINERITC.TTF',
#  'C:\\Windows\\Fonts\\FRADM.TTF',
#  'C:\\Windows\\Fonts\\constan.ttf',
#  'C:\\Windows\\Fonts\\arialbd.ttf',
#  'C:\\Windows\\Fonts\\cambriai.ttf',
#  'C:\\Windows\\Fonts\\Hancom Gothic Bold.ttf',
#  'C:\\Windows\\Fonts\\GILB____.TTF',
#  'C:\\Windows\\Fonts\\PERTIBD.TTF',
#  'C:\\Windows\\Fonts\\HARLOWSI.TTF',
#  'C:\\Windows\\Fonts\\HanSantteutDotum-Bold.ttf',
#  'C:\\Windows\\Fonts\\Candarai.ttf',
#  'C:\\Windows\\Fonts\\batang.ttc',
#  'C:\\Windows\\Fonts\\seguibl.ttf',
#  'C:\\Windows\\Fonts\\ERASDEMI.TTF',
#  'C:\\Windows\\Fonts\\LBRITED.TTF',
#  'C:\\Windows\\Fonts\\verdanai.ttf',
#  'C:\\Windows\\Fonts\\ELEPHNTI.TTF',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\CODE39-3.TTF',
#  'C:\\Windows\\Fonts\\consola.ttf',
#  'C:\\Windows\\Fonts\\BRITANIC.TTF',
#  'C:\\Windows\\Fonts\\PERBI___.TTF',
#  'C:\\Windows\\Fonts\\lucidatypewriterbold.ttf',
#  'C:\\Windows\\Fonts\\l_10646.ttf',
#  'C:\\Windows\\Fonts\\HANDotum.ttf',
#  'C:\\Windows\\Fonts\\LSANSI.TTF',
#  'C:\\Windows\\Fonts\\YuGothM.ttc',
#  'C:\\Windows\\Fonts\\comic.ttf',
#  'C:\\Windows\\Fonts\\courbd.ttf',
#  'C:\\Windows\\Fonts\\HMKMAMI.TTF',
#  'C:\\Windows\\Fonts\\segmdl2.ttf',
#  'C:\\Windows\\Fonts\\segoepr.ttf',
#  'C:\\Windows\\Fonts\\msgothic.ttc',
#  'C:\\Windows\\Fonts\\ROCC____.TTF',
#  'C:\\Windows\\Fonts\\palabi.ttf',
#  'C:\\Windows\\Fonts\\BOD_CI.TTF',
#  'C:\\Windows\\Fonts\\LHANDW.TTF',
#  'C:\\Windows\\Fonts\\Candaral.ttf',
#  'C:\\Windows\\Fonts\\TCMI____.TTF',
#  'C:\\Windows\\Fonts\\GILI____.TTF',
#  'C:\\Windows\\Fonts\\LBRITEI.TTF',
#  'C:\\Windows\\Fonts\\seguisli.ttf',
#  'C:\\Windows\\Fonts\\taile.ttf',
#  'C:\\Windows\\Fonts\\LFAX.TTF',
#  'C:\\Windows\\Fonts\\CENSCBK.TTF',
#  'C:\\Windows\\Fonts\\calibriz.ttf',
#  'C:\\Windows\\Fonts\\mingliub.ttc',
#  'C:\\Windows\\Fonts\\comici.ttf',
#  'C:\\Windows\\Fonts\\lucidabrightregular.ttf',
#  'C:\\Windows\\Fonts\\BOD_I.TTF',
#  'C:\\Windows\\Fonts\\BOD_CBI.TTF',
#  'C:\\Windows\\Fonts\\CASTELAR.TTF',
#  'C:\\Windows\\Fonts\\ROCK.TTF',
#  'C:\\Windows\\Fonts\\H2SA1M.TTF',
#  'C:\\Windows\\Fonts\\ROCKBI.TTF',
#  'C:\\Windows\\Fonts\\constanb.ttf',
#  'C:\\Windows\\Fonts\\LTYPEB.TTF',
#  'C:\\Windows\\Fonts\\H2GTRE.TTF',
#  'C:\\Windows\\Fonts\\calibrib.ttf',
#  'C:\\Windows\\Fonts\\HTOWERT.TTF',
#  'C:\\Windows\\Fonts\\BOD_CB.TTF',
#  'C:\\Windows\\Fonts\\COLONNA.TTF',
#  'C:\\Windows\\Fonts\\segoeuiz.ttf',
#  'C:\\Windows\\Fonts\\REFSPCL.TTF',
#  'C:\\Windows\\Fonts\\BAUHS93.TTF',
#  'C:\\Windows\\Fonts\\Candarab.ttf',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\ADVHC39D.TTF',
#  'C:\\Windows\\Fonts\\Nirmala.ttf',
#  'C:\\Windows\\Fonts\\REFSAN.TTF',
#  'C:\\Windows\\Fonts\\framdit.ttf',
#  'C:\\Windows\\Fonts\\LeelaUIb.ttf',
#  'C:\\Windows\\Fonts\\POORICH.TTF',
#  'C:\\Windows\\Fonts\\NGULIM.TTF',
#  'C:\\Windows\\Fonts\\BOOKOS.TTF',
#  'C:\\Windows\\Fonts\\seguibli.ttf',
#  'C:\\Windows\\Fonts\\STENCIL.TTF',
#  'C:\\Windows\\Fonts\\Inkfree.ttf',
#  'C:\\Windows\\Fonts\\segoescb.ttf',
#  'C:\\Windows\\Fonts\\javatext.ttf',
#  'C:\\Windows\\Fonts\\TCCB____.TTF',
#  'C:\\Windows\\Fonts\\AGENCYB.TTF',
#  'C:\\Windows\\Fonts\\BOD_BLAI.TTF',
#  'C:\\Windows\\Fonts\\HANBatangExtB.ttf',
#  'C:\\Windows\\Fonts\\georgia.ttf',
#  'C:\\Windows\\Fonts\\BOD_B.TTF',
#  'C:\\Windows\\Fonts\\NIAGENG.TTF',
#  'C:\\Windows\\Fonts\\segoeuii.ttf',
#  'C:\\Windows\\Fonts\\GARABD.TTF',
#  'C:\\Windows\\Fonts\\segoesc.ttf',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\Code128.ttf',
#  'C:\\Windows\\Fonts\\CALIST.TTF',
#  'C:\\Windows\\Fonts\\ERASMD.TTF',
#  'C:\\Windows\\Fonts\\malgun.ttf',
#  'C:\\Windows\\Fonts\\constani.ttf',
#  'C:\\Windows\\Fonts\\MAIAN.TTF',
#  'C:\\Windows\\Fonts\\GILSANUB.TTF',
#  'C:\\Windows\\Fonts\\CascadiaMono.ttf',
#  'C:\\Windows\\Fonts\\H2GPRM.TTF',
#  'C:\\Windows\\Fonts\\micross.ttf',
#  'C:\\Windows\\Fonts\\verdanab.ttf',
#  'C:\\Windows\\Fonts\\BOD_PSTC.TTF',
#  'C:\\Windows\\Fonts\\cambria.ttc',
#  'C:\\Windows\\Fonts\\timesbi.ttf',
#  'C:\\Windows\\Fonts\\GOTHICBI.TTF',
#  'C:\\Windows\\Fonts\\FRADMIT.TTF',
#  'C:\\Windows\\Fonts\\ANTQUABI.TTF',
#  'C:\\Windows\\Fonts\\GIL_____.TTF',
#  'C:\\Windows\\Fonts\\HMKMRHD.TTF',
#  'C:\\Windows\\Fonts\\COPRGTB.TTF',
#  'C:\\Program Files\\Common Files\\microsoft shared\\EQUATION\\MTEXTRA.TTF',
#  'C:\\Windows\\Fonts\\lucidasansdemioblique.ttf',
#  'C:\\Windows\\Fonts\\TCM_____.TTF',
#  'C:\\Windows\\Fonts\\FRAHV.TTF',
#  'C:\\Windows\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\segoeui.ttf',
#  'C:\\Windows\\Fonts\\mmrtext.ttf',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\ADVHC39C.TTF',
#  'C:\\Windows\\Fonts\\PRISTINA.TTF',
#  'C:\\Windows\\Fonts\\OLDENGL.TTF',
#  'C:\\Windows\\Fonts\\H2PORM.TTF',
#  'C:\\Windows\\Fonts\\gadugi.ttf',
#  'C:\\Windows\\Fonts\\verdana.ttf',
#  'C:\\Windows\\Fonts\\BROADW.TTF',
#  'C:\\Windows\\Fonts\\ariali.ttf',
#  'C:\\Windows\\Fonts\\monbaiti.ttf',
#  'C:\\Windows\\Fonts\\seguili.ttf',
#  'C:\\Windows\\Fonts\\GOTHICI.TTF',
#  'C:\\Windows\\Fonts\\comicz.ttf',
#  'C:\\Windows\\Fonts\\BOOKOSBI.TTF',
#  'C:\\Windows\\Fonts\\ALGER.TTF',
#  'C:\\Windows\\Fonts\\SCHLBKI.TTF',
#  'C:\\Windows\\Fonts\\TEMPSITC.TTF',
#  'C:\\Windows\\Fonts\\SNAP____.TTF',
#  'C:\\Windows\\Fonts\\HANDotumB.ttf',
#  'C:\\Windows\\Fonts\\seguisbi.ttf',
#  'C:\\Windows\\Fonts\\PLAYBILL.TTF',
#  'C:\\Windows\\Fonts\\trebucbd.ttf',
#  'C:\\Windows\\Fonts\\taileb.ttf',
#  'C:\\Windows\\Fonts\\COPRGTL.TTF',
#  'C:\\Windows\\Fonts\\FRABK.TTF',
#  'C:\\Windows\\Fonts\\trebuc.ttf',
#  'C:\\Windows\\Fonts\\SHOWG.TTF',
#  'C:\\Windows\\Fonts\\calibri.ttf',
#  'C:\\Windows\\Fonts\\LSANS.TTF',
#  'C:\\Windows\\Fonts\\BOOKOSI.TTF',
#  'C:\\Windows\\Fonts\\ntailu.ttf',
#  'C:\\Windows\\Fonts\\KUNSTLER.TTF',
#  'C:\\Windows\\Fonts\\GOTHIC.TTF',
#  'C:\\Windows\\Fonts\\WINGDNG2.TTF',
#  'C:\\Windows\\Fonts\\HanSantteutDotum-Regular.ttf',
#  'C:\\Windows\\Fonts\\JUMJA.TTF',
#  'C:\\Windows\\Fonts\\CURLZ___.TTF',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\ADVC39B.TTF',
#  'C:\\Windows\\Fonts\\ROCKB.TTF',
#  'C:\\Windows\\Fonts\\JUICE___.TTF',
#  'C:\\Windows\\Fonts\\GILBI___.TTF',
#  'C:\\Windows\\Fonts\\marlett.ttf',
#  'C:\\Windows\\Fonts\\CALISTBI.TTF',
#  'C:\\Windows\\Fonts\\HANBatangExtBB.ttf',
#  'C:\\Windows\\Fonts\\BKANT.TTF',
#  'C:\\Windows\\Fonts\\arial.ttf',
#  'C:\\Windows\\Fonts\\GOUDOSI.TTF',
#  'C:\\Windows\\Fonts\\COOPBL.TTF',
#  'C:\\Windows\\Fonts\\consolaz.ttf',
#  'C:\\Windows\\Fonts\\BELLB.TTF',
#  'C:\\Windows\\Fonts\\H2HDRM.TTF',
#  'C:\\Windows\\Fonts\\PAPYRUS.TTF',
#  'C:\\Windows\\Fonts\\BELL.TTF',
#  'C:\\Windows\\Fonts\\PERTILI.TTF',
#  'C:\\Windows\\Fonts\\BOOKOSB.TTF',
#  'C:\\Windows\\Fonts\\BSSYM7.TTF',
#  'C:\\Windows\\Fonts\\ITCBLKAD.TTF',
#  'C:\\Windows\\Fonts\\RAVIE.TTF',
#  'C:\\Windows\\Fonts\\FREESCPT.TTF',
#  'C:\\Windows\\Fonts\\FRAHVIT.TTF',
#  'C:\\Windows\\Fonts\\ROCCB___.TTF',
#  'C:\\Windows\\Fonts\\CHILLER.TTF',
#  'C:\\Windows\\Fonts\\BRLNSB.TTF',
#  'C:\\Windows\\Fonts\\georgiaz.ttf',
#  'C:\\Windows\\Fonts\\ROCKEB.TTF',
#  'C:\\Windows\\Fonts\\ITCKRIST.TTF',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\ADVC39C.TTF',
#  'C:\\Windows\\Fonts\\TCCM____.TTF',
#  'C:\\Windows\\Fonts\\BOD_R.TTF',
#  'C:\\Windows\\Fonts\\IMPRISHA.TTF',
#  'C:\\Windows\\Fonts\\msyi.ttf',
#  'C:\\Windows\\Fonts\\consolai.ttf',
#  'C:\\Windows\\Fonts\\HATTEN.TTF',
#  'C:\\Windows\\Fonts\\JOKERMAN.TTF',
#  'C:\\Windows\\Fonts\\segoeuisl.ttf',
#  'C:\\Windows\\Fonts\\FELIXTI.TTF',
#  'C:\\Windows\\Fonts\\symbol.ttf',
#  'C:\\Windows\\Fonts\\MATURASC.TTF',
#  'C:\\Windows\\Fonts\\ARLRDBD.TTF',
#  'C:\\Windows\\Fonts\\holomdl2.ttf',
#  'C:\\Windows\\Fonts\\seguiemj.ttf',
#  'C:\\Windows\\Fonts\\NIAGSOL.TTF',
#  'C:\\Windows\\Fonts\\georgiai.ttf',
#  'C:\\Windows\\Fonts\\mmrtextb.ttf',
#  'C:\\Windows\\Fonts\\RAGE.TTF',
#  'C:\\Windows\\Fonts\\wingding.ttf',
#  'C:\\Windows\\Fonts\\ebrimabd.ttf',
#  'C:\\Windows\\Fonts\\verdanaz.ttf',
#  'C:\\Windows\\Fonts\\ONYX.TTF',
#  'C:\\Windows\\Fonts\\segoeprb.ttf',
#  'C:\\Windows\\Fonts\\CALIFI.TTF',
#  'C:\\Windows\\Fonts\\LBRITEDI.TTF',
#  'C:\\Windows\\Fonts\\BASKVILL.TTF',
#  'C:\\Windows\\Fonts\\NirmalaB.ttf',
#  'C:\\Windows\\Fonts\\BRLNSR.TTF',
#  'C:\\Windows\\Fonts\\LFAXD.TTF',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\H2WULM.TTF',
#  'C:\\Windows\\Fonts\\lucidasansdemibold.ttf',
#  'C:\\Windows\\Fonts\\BOD_CR.TTF',
#  'C:\\Windows\\Fonts\\msjhbd.ttc',
#  'C:\\Windows\\Fonts\\sylfaen.ttf',
#  'C:\\Windows\\Fonts\\GLSNECB.TTF',
#  'C:\\Windows\\Fonts\\SCHLBKB.TTF',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\ADVHC39B.TTF',
#  'C:\\Windows\\Fonts\\lucidatypewriteroblique.ttf',
#  'C:\\Windows\\Fonts\\HANDotumExt.ttf',
#  'C:\\Windows\\Fonts\\ARIALNI.TTF',
#  'C:\\Windows\\Fonts\\GOUDYSTO.TTF',
#  'C:\\Windows\\Fonts\\GOUDOSB.TTF',
#  'C:\\Windows\\Fonts\\ERASBD.TTF',
#  'C:\\Windows\\Fonts\\consolab.ttf',
#  'C:\\Windows\\Fonts\\FTLTLT.TTF',
#  'C:\\Windows\\Fonts\\LEELAWAD.TTF',
#  'C:\\Windows\\Fonts\\HMFMMUEX.TTC',
#  'C:\\Windows\\Fonts\\CENTURY.TTF',
#  'C:\\Windows\\Fonts\\CascadiaCode.ttf',
#  'C:\\Windows\\Fonts\\FORTE.TTF',
#  'C:\\Windows\\Fonts\\msyhbd.ttc',
#  'C:\\Windows\\Fonts\\LTYPEO.TTF',
#  'C:\\Windows\\Fonts\\FRSCRIPT.TTF',
#  'C:\\Windows\\Fonts\\lucidabrightitalic.ttf',
#  'C:\\Windows\\Fonts\\corbel.ttf',
#  'C:\\Windows\\Fonts\\BRUSHSCI.TTF',
#  'C:\\Windows\\Fonts\\tahoma.ttf',
#  'C:\\Windows\\Fonts\\VLADIMIR.TTF',
#  'C:\\Windows\\Fonts\\GILC____.TTF',
#  'C:\\Windows\\Fonts\\lucidabrightdemiitalic.ttf',
#  'C:\\Windows\\Fonts\\Candaraz.ttf',
#  'C:\\Windows\\Fonts\\LSANSD.TTF',
#  'C:\\Windows\\Fonts\\times.ttf',
#  'C:\\Windows\\Fonts\\BERNHC.TTF',
#  'C:\\Windows\\Fonts\\WINGDNG3.TTF',
#  'C:\\Windows\\Fonts\\MAGNETOB.TTF',
#  'C:\\Windows\\Fonts\\palai.ttf',
#  'C:\\Windows\\Fonts\\HANBatang.ttf',
#  'C:\\Windows\\Fonts\\LCALLIG.TTF',
#  'C:\\Windows\\Fonts\\LeelUIsl.ttf',
#  'C:\\Windows\\Fonts\\georgiab.ttf',
#  'C:\\Windows\\Fonts\\MISTRAL.TTF',
#  'C:\\Windows\\Fonts\\framd.ttf',
#  'C:\\Windows\\Fonts\\lucidatypewriterregular.ttf',
#  'C:\\Windows\\Fonts\\gadugib.ttf',
#  'C:\\Windows\\Fonts\\comicbd.ttf',
#  'C:\\Windows\\Fonts\\lucidasansregular.ttf',
#  'C:\\Windows\\Fonts\\pala.ttf',
#  'C:\\Windows\\Fonts\\CENTAUR.TTF',
#  'C:\\Windows\\Fonts\\MSUIGHUR.TTF',
#  'C:\\Windows\\Fonts\\CALIFR.TTF',
#  'C:\\Windows\\Fonts\\ebrima.ttf',
#  'C:\\Windows\\Fonts\\CALISTI.TTF',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\ADVHC39A.TTF',
#  'C:\\Windows\\Fonts\\GLECB.TTF',
#  'C:\\Windows\\Fonts\\tahomabd.ttf',
#  'C:\\Windows\\Fonts\\ANTQUAI.TTF',
#  'C:\\Windows\\Fonts\\seguihis.ttf',
#  'C:\\Windows\\Fonts\\HMFMPYUN.TTF',
#  'C:\\Windows\\Fonts\\MOD20.TTF',
#  'C:\\Windows\\Fonts\\SitkaB.ttc',
#  'C:\\Windows\\Fonts\\H2GTRM.TTF',
#  'C:\\Windows\\Fonts\\palab.ttf',
#  'C:\\Windows\\Fonts\\H2PORL.TTF',
#  'C:\\Windows\\Fonts\\HYHWPEQ.TTF',
#  'C:\\Windows\\Fonts\\TCCEB.TTF',
#  'C:\\Windows\\Fonts\\HANBatangB.ttf',
#  'C:\\Windows\\Fonts\\LTYPE.TTF',
#  'C:\\Windows\\Fonts\\LFAXI.TTF',
#  'C:\\Windows\\Fonts\\calibril.ttf',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\ADVC39A.TTF',
#  'C:\\Windows\\Fonts\\HMFMOLD.TTF',
#  'C:\\Windows\\Fonts\\msjhl.ttc',
#  'C:\\Windows\\Fonts\\malgunsl.ttf',
#  'C:\\Windows\\Fonts\\seguisb.ttf',
#  'C:\\Windows\\Fonts\\lucidabrightdemibold.ttf',
#  'C:\\Windows\\Fonts\\HancomEQN.ttf',
#  'C:\\Windows\\Fonts\\trebucit.ttf',
#  'C:\\Windows\\Fonts\\malgunbd.ttf',
#  'C:\\Windows\\Fonts\\FRAMDCN.TTF',
#  'C:\\Windows\\Fonts\\AGENCYR.TTF',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\ADVC39E.TTF',
#  'C:\\Windows\\Fonts\\LATINWD.TTF',
#  'C:\\Windows\\Fonts\\TCB_____.TTF',
#  'C:\\Windows\\Fonts\\corbelz.ttf',
#  'C:\\Windows\\Fonts\\PARCHM.TTF',
#  'C:\\Windows\\Fonts\\gulim.ttc',
#  'C:\\Windows\\Fonts\\SitkaI.ttc',
#  'C:\\Windows\\Fonts\\VIVALDII.TTF',
#  'C:\\Windows\\Fonts\\LTYPEBO.TTF',
#  'C:\\Windows\\Fonts\\cour.ttf',
#  'C:\\Windows\\Fonts\\YuGothL.ttc',
#  'C:\\Windows\\Fonts\\himalaya.ttf',
#  'C:\\Windows\\Fonts\\lucidasansoblique.ttf',
#  'C:\\Windows\\Fonts\\BOD_BLAR.TTF',
#  'C:\\Windows\\Fonts\\LFAXDI.TTF',
#  'C:\\Windows\\Fonts\\GOTHICB.TTF',
#  'C:\\Windows\\Fonts\\NirmalaS.ttf',
#  'C:\\Windows\\Fonts\\corbelb.ttf',
#  'C:\\Windows\\Fonts\\msjh.ttc',
#  'C:\\Windows\\Fonts\\PER_____.TTF',
#  'C:\\Windows\\Fonts\\ITCEDSCR.TTF',
#  'C:\\Windows\\Fonts\\LBRITE.TTF',
#  'C:\\Windows\\Fonts\\ariblk.ttf',
#  'C:\\Windows\\Fonts\\GARAIT.TTF',
#  'C:\\Windows\\Fonts\\FRABKIT.TTF',
#  'C:\\Windows\\Fonts\\corbeli.ttf',
#  'C:\\Windows\\Fonts\\corbelli.ttf',
#  'C:\\Windows\\Fonts\\ARIALN.TTF',
#  'C:\\Windows\\Fonts\\MTCORSVA.TTF',
#  'C:\\Windows\\Fonts\\PERB____.TTF',
#  'C:\\Windows\\Fonts\\GOUDOS.TTF',
#  'C:\\Windows\\Fonts\\OCRAEXT.TTF',
#  'C:\\Windows\\Fonts\\ELEPHNT.TTF',
#  'C:\\Windows\\Fonts\\MSUIGHUB.TTF',
#  'C:\\Windows\\Fonts\\Sitka.ttc',
#  'C:\\Windows\\Fonts\\seguisym.ttf',
#  'C:\\Windows\\Fonts\\impact.ttf',
#  'C:\\Windows\\Fonts\\PALSCRI.TTF',
#  'C:\\Windows\\Fonts\\bahnschrift.ttf',
#  'C:\\Windows\\Fonts\\corbell.ttf',
#  'C:\\Windows\\Fonts\\HANWing2.ttf',
#  'C:\\Windows\\Fonts\\webdings.ttf',
#  'C:\\Windows\\Fonts\\ARIALNBI.TTF',
#  'C:\\Windows\\Fonts\\HTOWERTI.TTF',
#  'C:\\Windows\\Fonts\\lucidatypewriterboldoblique.ttf',
#  'C:\\Windows\\Fonts\\timesbd.ttf',
#  'C:\\Windows\\Fonts\\trebucbi.ttf',
#  'C:\\Windows\\Fonts\\CALISTB.TTF']

# %%
## 주피터 한글 깨짐 방지 - https://jimmy-ai.tistory.com/133
from matplotlib import rc
import matplotlib.font_manager as fm

# fm._rebuild()
fm.get_fontconfig_fonts()

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = 'C:\\Windows\\Fonts\\HYHWPEQ.TTF'
font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)
plt.rc('font', family='HYHWPEQ')

# %%
def visualization_data(df):
    crawling_time = df['정보 제공 시간']
    left_parking = df['주차 가능 대수']
    
    ## 데이터 시각화
    #ax = plt.gca()
    df.plot(kind='line', 
            x='정보 제공 시간', 
            y='주차 가능 대수', 
            color='blue', 
            figsize=(16, 16), 
            title='한강 주차 가능 대수 시각화'
           ) #, ax=ax)

    ## 시각화 결과 저장
    plt.savefig('output.png')

# %% [markdown]
# ## 데이터 시각화 - main

# %% [markdown]
# - 여의도 한강 공원 주차장 관련 데이터로 테스트 (23:39 주변 데이터 날짜 수정 완료 후)

# %%
df_Yeouido = pd.read_excel('df_Yeouido - 복사본.xlsx', engine='openpyxl')
df_Yeouido = df_Yeouido.drop(columns='Unnamed: 0')
df_Yeouido#.head(10)
# Out:
#               날짜 오전 오후    정보 제공 시간     주차장명                  주소  주차 가능 대수  \
# 0     2022-07-05    오후  9시 25분 22초  여의도1주차장  서울  영등포구 여의도동 86-5       633
# 1     2022-07-05    오후  9시 25분 22초  여의도2주차장  서울  영등포구 여의도동 84-4        25
# 2     2022-07-05    오후  9시 25분 22초  여의도3주차장  서울  영등포구 여의도동 83-6       788
# 3     2022-07-05    오후  9시 25분 22초  여의도4주차장    서울  영등포구 여의도동 19       134
# 4     2022-07-05    오후  9시 25분 22초  여의도5주차장    서울  영등포구 여의도동 63       201
# ...          ...   ...         ...      ...                 ...       ...
# 1080  2022-07-06    오후  3시 25분 37초  여의도1주차장  서울  영등포구 여의도동 86-5       377
# 1081  2022-07-06    오후  3시 25분 37초  여의도2주차장  서울  영등포구 여의도동 84-4         0
# 1082  2022-07-06    오후  3시 25분 37초  여의도3주차장  서울  영등포구 여의도동 83-6       339
# 1083  2022-07-06    오후  3시 25분 37초  여의도4주차장    서울  영등포구 여의도동 19         7
# 1084  2022-07-06    오후  3시 25분 37초  여의도5주차장    서울  영등포구 여의도동 63        30
#
#       주차 구획수      면적
# 0        462  17,483
# 1        171   6,630
# 2        800  21,630
# 3        141   4,861
# 4        217   9,918
# ...      ...     ...
# 1080     462  17,483
# 1081     171   6,630
# 1082     800  21,630
# 1083     141   4,861
# 1084     217   9,918
#
# [1085 rows x 8 columns]

# %%
## 데이터 수 확인
print('len data:', len(df_Yeouido))
# Out:
# len data: 1085

# %% [markdown]
# - 지역 내 주차장 명에 따라 데이터 groupby

# %%
## 주차장 명에 따라 데이터 groupby - 여의도

groups = df_Yeouido.groupby(df_Yeouido.주차장명)

df_Yeouido_1 = groups.get_group('여의도1주차장')
df_Yeouido_2 = groups.get_group('여의도2주차장')
df_Yeouido_3 = groups.get_group('여의도3주차장')
df_Yeouido_4 = groups.get_group('여의도4주차장')
df_Yeouido_5 = groups.get_group('여의도5주차장')

# %%
print('len df_Yeouido_1:', len(df_Yeouido_1))
df_Yeouido_1
# Out:
# len df_Yeouido_1: 217
#               날짜 오전 오후    정보 제공 시간     주차장명                  주소  주차 가능 대수  \
# 0     2022-07-05    오후  9시 25분 22초  여의도1주차장  서울  영등포구 여의도동 86-5       633
# 5     2022-07-05    오후  9시 30분 17초  여의도1주차장  서울  영등포구 여의도동 86-5       629
# 10    2022-07-05    오후  9시 35분 01초  여의도1주차장  서울  영등포구 여의도동 86-5       635
# 15    2022-07-05    오후  9시 40분 33초  여의도1주차장  서울  영등포구 여의도동 86-5       647
# 20    2022-07-05    오후  9시 45분 29초  여의도1주차장  서울  영등포구 여의도동 86-5       659
# ...          ...   ...         ...      ...                 ...       ...
# 1060  2022-07-06    오후  3시 05분 26초  여의도1주차장  서울  영등포구 여의도동 86-5       368
# 1065  2022-07-06    오후  3시 10분 31초  여의도1주차장  서울  영등포구 여의도동 86-5       372
# 1070  2022-07-06    오후  3시 15분 21초  여의도1주차장  서울  영등포구 여의도동 86-5       377
# 1075  2022-07-06    오후  3시 20분 29초  여의도1주차장  서울  영등포구 여의도동 86-5       385
# 1080  2022-07-06    오후  3시 25분 37초  여의도1주차장  서울  영등포구 여의도동 86-5       377
#
#       주차 구획수      면적
# 0        462  17,483
# 5        462  17,483
# 10       462  17,483
# 15       462  17,483
# 20       462  17,483
# ...      ...     ...
# 1060     462  17,483
# 1065     462  17,483
# 1070     462  17,483
# 1075     462  17,483
# 1080     462  17,483
#
# [217 rows x 8 columns]

# %%
print('len df_Yeouido_2:', len(df_Yeouido_2))
df_Yeouido_2
# Out:
# len df_Yeouido_2: 217
#               날짜 오전 오후    정보 제공 시간     주차장명                  주소  주차 가능 대수  \
# 1     2022-07-05    오후  9시 25분 22초  여의도2주차장  서울  영등포구 여의도동 84-4        25
# 6     2022-07-05    오후  9시 30분 17초  여의도2주차장  서울  영등포구 여의도동 84-4        24
# 11    2022-07-05    오후  9시 35분 01초  여의도2주차장  서울  영등포구 여의도동 84-4        24
# 16    2022-07-05    오후  9시 40분 33초  여의도2주차장  서울  영등포구 여의도동 84-4        26
# 21    2022-07-05    오후  9시 45분 29초  여의도2주차장  서울  영등포구 여의도동 84-4        25
# ...          ...   ...         ...      ...                 ...       ...
# 1061  2022-07-06    오후  3시 05분 26초  여의도2주차장  서울  영등포구 여의도동 84-4         0
# 1066  2022-07-06    오후  3시 10분 31초  여의도2주차장  서울  영등포구 여의도동 84-4         0
# 1071  2022-07-06    오후  3시 15분 21초  여의도2주차장  서울  영등포구 여의도동 84-4         0
# 1076  2022-07-06    오후  3시 20분 29초  여의도2주차장  서울  영등포구 여의도동 84-4         0
# 1081  2022-07-06    오후  3시 25분 37초  여의도2주차장  서울  영등포구 여의도동 84-4         0
#
#       주차 구획수     면적
# 1        171  6,630
# 6        171  6,630
# 11       171  6,630
# 16       171  6,630
# 21       171  6,630
# ...      ...    ...
# 1061     171  6,630
# 1066     171  6,630
# 1071     171  6,630
# 1076     171  6,630
# 1081     171  6,630
#
# [217 rows x 8 columns]

# %%
print('len df_Yeouido_3:', len(df_Yeouido_3))
df_Yeouido_3
# Out:
# len df_Yeouido_3: 217
#               날짜 오전 오후    정보 제공 시간     주차장명                  주소  주차 가능 대수  \
# 2     2022-07-05    오후  9시 25분 22초  여의도3주차장  서울  영등포구 여의도동 83-6       788
# 7     2022-07-05    오후  9시 30분 17초  여의도3주차장  서울  영등포구 여의도동 83-6       790
# 12    2022-07-05    오후  9시 35분 01초  여의도3주차장  서울  영등포구 여의도동 83-6       795
# 17    2022-07-05    오후  9시 40분 33초  여의도3주차장  서울  영등포구 여의도동 83-6       796
# 22    2022-07-05    오후  9시 45분 29초  여의도3주차장  서울  영등포구 여의도동 83-6       799
# ...          ...   ...         ...      ...                 ...       ...
# 1062  2022-07-06    오후  3시 05분 26초  여의도3주차장  서울  영등포구 여의도동 83-6       338
# 1067  2022-07-06    오후  3시 10분 31초  여의도3주차장  서울  영등포구 여의도동 83-6       335
# 1072  2022-07-06    오후  3시 15분 21초  여의도3주차장  서울  영등포구 여의도동 83-6       333
# 1077  2022-07-06    오후  3시 20분 29초  여의도3주차장  서울  영등포구 여의도동 83-6       336
# 1082  2022-07-06    오후  3시 25분 37초  여의도3주차장  서울  영등포구 여의도동 83-6       339
#
#       주차 구획수      면적
# 2        800  21,630
# 7        800  21,630
# 12       800  21,630
# 17       800  21,630
# 22       800  21,630
# ...      ...     ...
# 1062     800  21,630
# 1067     800  21,630
# 1072     800  21,630
# 1077     800  21,630
# 1082     800  21,630
#
# [217 rows x 8 columns]

# %%
print('len df_Yeouido_4:', len(df_Yeouido_4))
df_Yeouido_4
# Out:
# len df_Yeouido_4: 217
#               날짜 오전 오후    정보 제공 시간     주차장명                주소  주차 가능 대수  \
# 3     2022-07-05    오후  9시 25분 22초  여의도4주차장  서울  영등포구 여의도동 19       134
# 8     2022-07-05    오후  9시 30분 17초  여의도4주차장  서울  영등포구 여의도동 19       133
# 13    2022-07-05    오후  9시 35분 01초  여의도4주차장  서울  영등포구 여의도동 19       135
# 18    2022-07-05    오후  9시 40분 33초  여의도4주차장  서울  영등포구 여의도동 19       137
# 23    2022-07-05    오후  9시 45분 29초  여의도4주차장  서울  영등포구 여의도동 19       137
# ...          ...   ...         ...      ...               ...       ...
# 1063  2022-07-06    오후  3시 05분 26초  여의도4주차장  서울  영등포구 여의도동 19         3
# 1068  2022-07-06    오후  3시 10분 31초  여의도4주차장  서울  영등포구 여의도동 19         3
# 1073  2022-07-06    오후  3시 15분 21초  여의도4주차장  서울  영등포구 여의도동 19         5
# 1078  2022-07-06    오후  3시 20분 29초  여의도4주차장  서울  영등포구 여의도동 19         4
# 1083  2022-07-06    오후  3시 25분 37초  여의도4주차장  서울  영등포구 여의도동 19         7
#
#       주차 구획수     면적
# 3        141  4,861
# 8        141  4,861
# 13       141  4,861
# 18       141  4,861
# 23       141  4,861
# ...      ...    ...
# 1063     141  4,861
# 1068     141  4,861
# 1073     141  4,861
# 1078     141  4,861
# 1083     141  4,861
#
# [217 rows x 8 columns]

# %%
print('len df_Yeouido_5:', len(df_Yeouido_5))
df_Yeouido_5
# Out:
# len df_Yeouido_5: 217
#               날짜 오전 오후    정보 제공 시간     주차장명                주소  주차 가능 대수  \
# 4     2022-07-05    오후  9시 25분 22초  여의도5주차장  서울  영등포구 여의도동 63       201
# 9     2022-07-05    오후  9시 30분 17초  여의도5주차장  서울  영등포구 여의도동 63       201
# 14    2022-07-05    오후  9시 35분 01초  여의도5주차장  서울  영등포구 여의도동 63       201
# 19    2022-07-05    오후  9시 40분 33초  여의도5주차장  서울  영등포구 여의도동 63       202
# 24    2022-07-05    오후  9시 45분 29초  여의도5주차장  서울  영등포구 여의도동 63       201
# ...          ...   ...         ...      ...               ...       ...
# 1064  2022-07-06    오후  3시 05분 26초  여의도5주차장  서울  영등포구 여의도동 63        29
# 1069  2022-07-06    오후  3시 10분 31초  여의도5주차장  서울  영등포구 여의도동 63        26
# 1074  2022-07-06    오후  3시 15분 21초  여의도5주차장  서울  영등포구 여의도동 63        27
# 1079  2022-07-06    오후  3시 20분 29초  여의도5주차장  서울  영등포구 여의도동 63        29
# 1084  2022-07-06    오후  3시 25분 37초  여의도5주차장  서울  영등포구 여의도동 63        30
#
#       주차 구획수     면적
# 4        217  9,918
# 9        217  9,918
# 14       217  9,918
# 19       217  9,918
# 24       217  9,918
# ...      ...    ...
# 1064     217  9,918
# 1069     217  9,918
# 1074     217  9,918
# 1079     217  9,918
# 1084     217  9,918
#
# [217 rows x 8 columns]

# %% [markdown]
# - 주차장 명을 기준으로 groupby한 데이터를 다시 날짜 기준으로 groupby
# - 단, 테스트는 여의도 22년 07월 06일 데이터를 사용하여 진행함

# %% [markdown]
# - 여의도1주차장 22년 07월 06일 시간 - 혼잡도 시각화

# %%
## 사용률 열 추가
'''
df_Yeouido_1 = preprocessing(df_Yeouido_1)
df_Yeouido_1'''
# Out:
# '\ndf_Yeouido_1 = preprocessing(df_Yeouido_1)\ndf_Yeouido_1'

# %%
## 날짜 별 groupby
groups_df_Yeouido_1 = df_Yeouido_1.groupby(df_Yeouido.날짜)
groups_df_Yeouido_2 = df_Yeouido_2.groupby(df_Yeouido.날짜)
groups_df_Yeouido_3 = df_Yeouido_3.groupby(df_Yeouido.날짜)
groups_df_Yeouido_4 = df_Yeouido_4.groupby(df_Yeouido.날짜)
groups_df_Yeouido_5 = df_Yeouido_5.groupby(df_Yeouido.날짜)

df_Yeouido_1_220706 = groups_df_Yeouido_1.get_group('2022-07-06')
df_Yeouido_2_220706 = groups_df_Yeouido_2.get_group('2022-07-06')
df_Yeouido_3_220706 = groups_df_Yeouido_3.get_group('2022-07-06')
df_Yeouido_4_220706 = groups_df_Yeouido_4.get_group('2022-07-06')
df_Yeouido_5_220706 = groups_df_Yeouido_5.get_group('2022-07-06')

# %%
print('len df_Yeouido_1_220706:', len(df_Yeouido_1_220706))
df_Yeouido_1_220706
# Out:
# len df_Yeouido_1_220706: 186
#               날짜 오전 오후     정보 제공 시간     주차장명                  주소  주차 가능 대수  \
# 155   2022-07-06    오전  12시 00분 18초  여의도1주차장  서울  영등포구 여의도동 86-5       742
# 160   2022-07-06    오전  12시 05분 14초  여의도1주차장  서울  영등포구 여의도동 86-5       744
# 165   2022-07-06    오전  12시 10분 10초  여의도1주차장  서울  영등포구 여의도동 86-5       743
# 170   2022-07-06    오전  12시 15분 25초  여의도1주차장  서울  영등포구 여의도동 86-5       740
# 175   2022-07-06    오전  12시 20분 10초  여의도1주차장  서울  영등포구 여의도동 86-5       742
# ...          ...   ...          ...      ...                 ...       ...
# 1060  2022-07-06    오후   3시 05분 26초  여의도1주차장  서울  영등포구 여의도동 86-5       368
# 1065  2022-07-06    오후   3시 10분 31초  여의도1주차장  서울  영등포구 여의도동 86-5       372
# 1070  2022-07-06    오후   3시 15분 21초  여의도1주차장  서울  영등포구 여의도동 86-5       377
# 1075  2022-07-06    오후   3시 20분 29초  여의도1주차장  서울  영등포구 여의도동 86-5       385
# 1080  2022-07-06    오후   3시 25분 37초  여의도1주차장  서울  영등포구 여의도동 86-5       377
#
#       주차 구획수      면적
# 155      462  17,483
# 160      462  17,483
# 165      462  17,483
# 170      462  17,483
# 175      462  17,483
# ...      ...     ...
# 1060     462  17,483
# 1065     462  17,483
# 1070     462  17,483
# 1075     462  17,483
# 1080     462  17,483
#
# [186 rows x 8 columns]

# %%
## 시간 - 주차 가능 대수 시각화
visualization_data(df_Yeouido_1_220706)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
visualization_data(df_Yeouido_2_220706)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
visualization_data(df_Yeouido_3_220706)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# - 광나루 한강 공원 주차장 관련 데이터로 테스트 (23:39 주변 데이터 날짜 수정 완료 후)

# %%
df_Jamsil = pd.read_excel('df_Jamsil - 복사본.xlsx', engine='openpyxl')
df_Jamsil = df_Jamsil.drop(columns='Unnamed: 0')
df_Jamsil#.head(10)
# Out:
#              날짜 오전 오후    정보 제공 시간          주차장명               주소  주차 가능 대수  \
# 0    2022-07-05    오후  9시 25분 22초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       247
# 1    2022-07-05    오후  9시 30분 17초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       252
# 2    2022-07-05    오후  9시 35분 01초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       246
# 3    2022-07-05    오후  9시 40분 33초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       251
# 4    2022-07-05    오후  9시 45분 29초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       260
# ..          ...   ...         ...           ...              ...       ...
# 224  2022-07-06    오후  4시 05분 25초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       248
# 225  2022-07-06    오후  4시 10분 24초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       249
# 226  2022-07-06    오후  4시 15분 03초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       258
# 227  2022-07-06    오후  4시 20분 06초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       256
# 228  2022-07-06    오후  4시 25분 02초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       252
#
#      주차 구획수      면적
# 0       471  15,055
# 1       471  15,055
# 2       471  15,055
# 3       471  15,055
# 4       471  15,055
# ..      ...     ...
# 224     471  15,055
# 225     471  15,055
# 226     471  15,055
# 227     471  15,055
# 228     471  15,055
#
# [229 rows x 8 columns]

# %%
## 데이터 수 확인
print('len data:', len(df_Jamsil))
# Out:
# len data: 229

# %% [markdown]
# - 지역이 1 개 이므로, 날짜에 따라서만 groupby

# %%
## 날짜 별 groupby
groups_df_Jamsil = df_Jamsil.groupby(df_Jamsil.날짜)

df_Jamsil_220706 = groups_df_Jamsil.get_group('2022-07-06')

# %%
print('len df_Jamsil_220706:', len(df_Jamsil_220706))
df_Jamsil_220706
# Out:
# len df_Jamsil_220706: 198
#              날짜 오전 오후     정보 제공 시간          주차장명               주소  주차 가능 대수  \
# 31   2022-07-06    오전  12시 00분 18초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       351
# 32   2022-07-06    오전  12시 05분 14초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       354
# 33   2022-07-06    오전  12시 10분 10초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       355
# 34   2022-07-06    오전  12시 15분 25초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       354
# 35   2022-07-06    오전  12시 20분 10초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       356
# ..          ...   ...          ...           ...              ...       ...
# 224  2022-07-06    오후   4시 05분 25초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       248
# 225  2022-07-06    오후   4시 10분 24초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       249
# 226  2022-07-06    오후   4시 15분 03초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       258
# 227  2022-07-06    오후   4시 20분 06초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       256
# 228  2022-07-06    오후   4시 25분 02초  잠실1,2,3,4주차장  서울  송파구 잠실동 1-1       252
#
#      주차 구획수      면적
# 31      471  15,055
# 32      471  15,055
# 33      471  15,055
# 34      471  15,055
# 35      471  15,055
# ..      ...     ...
# 224     471  15,055
# 225     471  15,055
# 226     471  15,055
# 227     471  15,055
# 228     471  15,055
#
# [198 rows x 8 columns]

# %%
visualization_data(df_Jamsil_220706)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# - 강서 한강 공원 주차장 관련 데이터로 테스트 (23:39 주변 데이터 날짜 수정 완료 후)

# %%
df_Gangseo = pd.read_excel('df_Gangseo - 복사본.xlsx', engine='openpyxl')
df_Gangseo = df_Gangseo.drop(columns='Unnamed: 0')
df_Gangseo#.head(10)
# Out:
#              날짜 오전 오후    정보 제공 시간    주차장명              주소  주차 가능 대수  주차 구획수  \
# 0    2022-07-05    오후  9시 25분 22초  강서1주차장  서울  강서구 방화동 61        23      53
# 1    2022-07-05    오후  9시 30분 17초  강서1주차장  서울  강서구 방화동 61        24      53
# 2    2022-07-05    오후  9시 35분 01초  강서1주차장  서울  강서구 방화동 61        21      53
# 3    2022-07-05    오후  9시 40분 33초  강서1주차장  서울  강서구 방화동 61        21      53
# 4    2022-07-05    오후  9시 45분 29초  강서1주차장  서울  강서구 방화동 61        18      53
# ..          ...   ...         ...     ...             ...       ...     ...
# 226  2022-07-06    오후  4시 15분 03초  강서1주차장  서울  강서구 방화동 61        40      53
# 227  2022-07-06    오후  4시 20분 06초  강서1주차장  서울  강서구 방화동 61        40      53
# 228  2022-07-06    오후  4시 25분 02초  강서1주차장  서울  강서구 방화동 61        40      53
# 229  2022-07-06    오후  4시 30분 00초  강서1주차장  서울  강서구 방화동 61        39      53
# 230  2022-07-06    오후  4시 35분 40초  강서1주차장  서울  강서구 방화동 61        40      53
#
#         면적
# 0    2,184
# 1    2,184
# 2    2,184
# 3    2,184
# 4    2,184
# ..     ...
# 226  2,184
# 227  2,184
# 228  2,184
# 229  2,184
# 230  2,184
#
# [231 rows x 8 columns]

# %%
## 데이터 수 확인
print('len data:', len(df_Gangseo))
# Out:
# len data: 231

# %% [markdown]
# - 지역이 1 개 이므로, 날짜에 따라서만 groupby

# %%
## 날짜 별 groupby
groups_df_Gangseo = df_Gangseo.groupby(df_Gangseo.날짜)

df_Gangseo_220706 = groups_df_Gangseo.get_group('2022-07-06')

# %%
print('len df_Gangseo_220706:', len(df_Gangseo_220706))
df_Gangseo_220706
# Out:
# len df_Gangseo_220706: 208
#              날짜 오전 오후     정보 제공 시간    주차장명              주소  주차 가능 대수  주차 구획수  \
# 23   2022-07-06    오후  11시 20분 10초  강서1주차장  서울  강서구 방화동 61        38      53
# 24   2022-07-06    오후  11시 25분 01초  강서1주차장  서울  강서구 방화동 61        39      53
# 25   2022-07-06    오후  11시 30분 27초  강서1주차장  서울  강서구 방화동 61        38      53
# 26   2022-07-06    오후  11시 35분 07초  강서1주차장  서울  강서구 방화동 61        38      53
# 27   2022-07-06    오후  11시 40분 03초  강서1주차장  서울  강서구 방화동 61        38      53
# ..          ...   ...          ...     ...             ...       ...     ...
# 226  2022-07-06    오후   4시 15분 03초  강서1주차장  서울  강서구 방화동 61        40      53
# 227  2022-07-06    오후   4시 20분 06초  강서1주차장  서울  강서구 방화동 61        40      53
# 228  2022-07-06    오후   4시 25분 02초  강서1주차장  서울  강서구 방화동 61        40      53
# 229  2022-07-06    오후   4시 30분 00초  강서1주차장  서울  강서구 방화동 61        39      53
# 230  2022-07-06    오후   4시 35분 40초  강서1주차장  서울  강서구 방화동 61        40      53
#
#         면적
# 23   2,184
# 24   2,184
# 25   2,184
# 26   2,184
# 27   2,184
# ..     ...
# 226  2,184
# 227  2,184
# 228  2,184
# 229  2,184
# 230  2,184
#
# [208 rows x 8 columns]

# %%
visualization_data(df_Gangseo_220706)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0, flags=flags)
